# %% [markdown]
# # Test Data Prediction Regression

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# %% [markdown]
# ## Scaled Data

# %%
df = pd.read_csv(r'C:\Users\FARJAD FARHAT\Downloads\MLProject\Phase3\TrainModelDataFinalScl.csv')

# %%
y = df['departure_delay']
X = df.drop(columns=['departure_delay'])

# %%
dfTest = pd.read_csv('TestModelDataFinal.csv')

# %%
print(len(X.columns),len(dfTest.columns))
# Out:
# 84 84

# %% [markdown]
# #### Random Forest

# %%
model = RandomForestRegressor(max_depth=None, min_samples_leaf=1, min_samples_split = 2, n_estimators = 300,n_jobs= -1)
model.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=300, n_jobs=-1)

# %%
y_pred = model.predict(dfTest)

# %%
data = pd.DataFrame(
    {
        "ID" : [i for i in range(1 , len(y_pred)+1)],
        "Delay" : y_pred
    }
)

# %%
data.to_csv('PredictionsScaledRfReg.csv', index=False)

# %% [markdown]
# #### Linear Regressor

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(dfTest)

# %%
data = pd.DataFrame(
    {
        "ID" : [i for i in range(1 , len(y_pred)+1)],
        "Delay" : y_pred
    }
)

# %%
data.to_csv('PredictionsScaledLrReg.csv', index=False)

# %% [markdown]
# #### Gradient Boosting Regressor

# %%
model = GradientBoostingRegressor(learning_rate = 0.1, max_depth = 5, min_samples_split = 2, n_estimators = 200)
model.fit(X, y)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=200)

# %%
y_pred = model.predict(dfTest)

# %%
data = pd.DataFrame(
    {
        "ID" : [i for i in range(1 , len(y_pred)+1)],
        "Delay" : y_pred
    }
)

# %%
data.to_csv('PredictionsScaledGbReg.csv', index=False)

# %% [markdown]
# ## UnScaled Data

# %%
df = pd.read_csv(r'C:\Users\FARJAD FARHAT\Downloads\MLProject\Phase3\TrainModelDataFinalNotScl.csv')

# %%
y = df['departure_delay']
X = df.drop(columns=['departure_delay'])

# %%
dfTest = pd.read_csv('TestModelDataFinal.csv')

# %%
print(len(X.columns),len(dfTest.columns))
# Out:
# 84 84

# %% [markdown]
# #### Random Forest

# %%
model = RandomForestRegressor(max_depth = 20, min_samples_leaf = 2, min_samples_split = 5, n_estimators = 300)
model.fit(X, y)
# Out:
# RandomForestRegressor(max_depth=20, min_samples_leaf=2, min_samples_split=5,
#                       n_estimators=300)

# %%
y_pred = model.predict(dfTest)

# %%
data = pd.DataFrame(
    {
        "ID" : [i for i in range(1 , len(y_pred)+1)],
        "Delay" : y_pred
    }
)

# %%
data.to_csv('PredictionsNotScaledRfReg.csv', index=False)

# %% [markdown]
# #### Linear Regressor

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(dfTest)

# %%
data = pd.DataFrame(
    {
        "ID" : [i for i in range(1 , len(y_pred)+1)],
        "Delay" : y_pred
    }
)

# %%
data.to_csv('PredictionsNotScaledLrReg.csv', index=False)

# %% [markdown]
# #### Gradient Boosting Regressor

# %%
model = GradientBoostingRegressor(learning_rate = 0.01, max_depth = 5, min_samples_split = 2, n_estimators = 100)
model.fit(X, y)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=5)

# %%
y_pred = model.predict(dfTest)

# %%
data = pd.DataFrame(
    {
        "ID" : [i for i in range(1 , len(y_pred)+1)],
        "Delay" : y_pred
    }
)

# %%
data.to_csv('PredictionsNotScaledGbReg.csv', index=False)
